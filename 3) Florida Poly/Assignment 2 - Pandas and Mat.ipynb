# %%
import pandas as pd 
import numpy as np
s = pd.Series([4, -5, 2, 6], index=['a', 'b', 'c', 'd'])
data = {'Course': ['COP4531', 'COP4656', 'CAP4612'],
     'Location': ['IST 65', 'IST 65', 'IST 67'],
     'GPA': [3.5, 3.8, 4.0]}
df = pd.DataFrame(data, columns=['Course', 'Location', 'GPA'])
print(pd.DataFrame(np.random.rand(4,5)).head(1))
# Out:
#           0         1         2         3         4
# 0  0.645935  0.412462  0.242646  0.978285  0.010752

# %%
print(df[1:])
# Out:
#     Course Location  GPA
# 1  COP4656   IST 65  3.8
# 2  CAP4612   IST 67  4.0

# %%
print(df[0:-1])
# Out:
#     Course Location  GPA
# 0  COP4531   IST 65  3.5
# 1  COP4656   IST 65  3.8

# %%
print(df.iloc[[0]])
# Out:
#     Course Location  GPA
# 0  COP4531   IST 65  3.5

# %%
print(df.iloc[[0],[0]])
# Out:
#     Course
# 0  COP4531

# %%
df.iat[0,0]
# Out:
# 'COP4531'

# %%
print(df.loc[[0], ['Course']])
# Out:
#     Course
# 0  COP4531

# %%
df.shape
# Out:
# (3, 3)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.tail(1)
# Out:
#     Course Location  GPA
# 2  CAP4612   IST 67  4.0

# %%
df.count()
# Out:
# Course      3
# Location    3
# GPA         3
# dtype: int64

# %%
df['Location'].value_counts()
# Out:
# IST 65    2
# IST 67    1
# Name: Location, dtype: int64

# %%
df['GPA'].sum()
# Out:
# 11.3

# %%
f = lambda x:x*2
df['GPA'].apply(f)
# Out:
# 0    7.0
# 1    7.6
# 2    8.0
# Name: GPA, dtype: float64

# %%
s3 = pd.Series([5, -2, 4], index=['a', 'c', 'd'])
s.sub(s3,fill_value=0)
# Out:
# a   -1.0
# b   -5.0
# c    4.0
# d    2.0
# dtype: float64

# %%
print(pd.notnull(df1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-144c7ebf8f7f> in <module>
# ----> 1 print(pd.notnull(df1))
#
# NameError: name 'df1' is not defined

# %%
print(pd.notnull(df))
# Out:
#    Course  Location   GPA
# 0    True      True  True
# 1    True      True  True
# 2    True      True  True

# %%
df.to_csv('myDataFrame.csv')
df_load = pd.read_csv( 'myDataFrame.csv', header=None)
print(df_load[1])
# Out:
# 0     Course
# 1    COP4531
# 2    COP4656
# 3    CAP4612
# Name: 1, dtype: object

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
x = np.linspace(0,10,1000)
y = 2*x
plt.plot(x, np.cos(x))
plt.plot(x, y, color='blue', linestyle='--')
plt.plot(x, np.log(x+0.001), color='0.75',linestyle='-.')
plt.plot(x, x, color='#FFDD44',linestyle='--')

# %%
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = (30 * np.random.rand(N))**2
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %%
labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]
x = np.arange(len(labels))
fig, ax = plt.subplots()
rects1 = ax.bar(x - 0.1, men_means, 0.2, label='Men')
rects2 = ax.bar(x + 0.1, women_means, 0.2, label='Women')
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()
